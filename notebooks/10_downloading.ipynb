# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import os

def save_model():
    base_model_name = "Qwen/Qwen3-4B-Instruct-2507"
    adapter_dir = "../model/archive/"
    offload_dir = "../offload/"
    
    # Create offload directory if it doesn't exist
    os.makedirs(offload_dir, exist_ok=True)
    
    print(f"Loading base model: {base_model_name}")
    base_model = AutoModelForCausalLM.from_pretrained(
        base_model_name,
        torch_dtype=torch.float16,
        device_map="auto",
        offload_folder=offload_dir,  # Only this parameter is needed
        low_cpu_mem_usage=True
    )
    tokenizer = AutoTokenizer.from_pretrained(base_model_name)
    
    print(f"Loading LoRA adapter from: {adapter_dir}")
    model = PeftModel.from_pretrained(base_model, adapter_dir)
    
    # Merge and unload adapter
    print("Merging LoRA weights into base model...")
    model = model.merge_and_unload()
    
    # Save merged model
    output_dir = "/kaggle/working/merged_model"
    os.makedirs(output_dir, exist_ok=True)
    
    print("Saving merged model...")
    model.save_pretrained(output_dir, safe_serialization=True)
    tokenizer.save_pretrained(output_dir)
    print(f"Merged model saved at: {output_dir}")

save_model()
# Out:
# Loading base model: Qwen/Qwen3-4B-Instruct-2507
# Loading checkpoint shards: 100%|██████████| 3/3 [00:10<00:00,  3.45s/it]
# Some parameters are on the meta device because they were offloaded to the disk.
# Loading LoRA adapter from: ../model/
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/Documents/Coding/Hackathons/ARC/ARC-AGI-2/venv/lib/python3.13/site-packages/peft/config.py:262, in PeftConfigMixin._get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     261 try:
# --> 262     config_file = hf_hub_download(
#     263         model_id,
#     264         CONFIG_NAME,
#     265         **hf_hub_download_kwargs,
#     266     )
#     267 except Exception:
#
# File ~/Documents/Coding/Hackathons/ARC/ARC-AGI-2/venv/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/Documents/Coding/Hackathons/ARC/ARC-AGI-2/venv/lib/python3.13/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '../model/'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 40
#      37     tokenizer.save_pretrained(output_dir)
#      38     print(f"Merged model saved at: {output_dir}")
# ---> 40 save_model()
#
# Cell In[10], line 25, in save_model()
#      22 tokenizer = AutoTokenizer.from_pretrained(base_model_name)
#      24 print(f"Loading LoRA adapter from: {adapter_dir}")
# ---> 25 model = PeftModel.from_pretrained(base_model, adapter_dir)
#      27 # Merge and unload adapter
#      28 print("Merging LoRA weights into base model...")
#
# File ~/Documents/Coding/Hackathons/ARC/ARC-AGI-2/venv/lib/python3.13/site-packages/peft/peft_model.py:440, in PeftModel.from_pretrained(cls, model, model_id, adapter_name, is_trainable, config, autocast_adapter_dtype, ephemeral_gpu_offload, low_cpu_mem_usage, key_mapping, **kwargs)
#     437 # load the config
#     438 if config is None:
#     439     config = PEFT_TYPE_TO_CONFIG_MAPPING[
# --> 440         PeftConfig._get_peft_type(
#     441             model_id,
#     442             subfolder=kwargs.get("subfolder", None),
#     443             revision=kwargs.get("revision", None),
#     444             cache_dir=kwargs.get("cache_dir", None),
#     445             use_auth_token=kwargs.get("use_auth_token", None),
#     446             token=kwargs.get("token", None),
#     447         )
#     448     ].from_pretrained(model_id, **kwargs)
#     449 elif isinstance(config, PeftConfig):
#     450     config.inference_mode = not is_trainable
#
# File ~/Documents/Coding/Hackathons/ARC/ARC-AGI-2/venv/lib/python3.13/site-packages/peft/config.py:268, in PeftConfigMixin._get_peft_type(cls, model_id, **hf_hub_download_kwargs)
#     262         config_file = hf_hub_download(
#     263             model_id,
#     264             CONFIG_NAME,
#     265             **hf_hub_download_kwargs,
#     266         )
#     267     except Exception:
# --> 268         raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
#     270 loaded_attributes = cls.from_json_file(config_file)
#     271 return loaded_attributes["peft_type"]
#
# ValueError: Can't find 'adapter_config.json' at '../model/'
