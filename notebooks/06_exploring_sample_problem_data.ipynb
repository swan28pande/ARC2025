# %%
import json
import sys
sys.path.append('..')
import src.utils.visualizer as visualizer

# %%
training_challenges_path = "../data/arc-agi-2025/problem_augmented/arc-agi_training_challenges.json"
original_challenges_path = "../data/arc-agi-2025/raw/arc-agi_training_challenges.json"

# %%
with open(training_challenges_path, 'r') as f:
    training_challenges = json.load(f)

# %%
with open(original_challenges_path, 'r') as f:
    original_challenges = json.load(f)

# %%
print(len(original_challenges))
# Out:
# 1000

# %%
print(len(training_challenges))
# Out:
# 25824

# %%
print(training_challenges.keys())
# Out:
# dict_keys(['00576224_0', '00576224_1', '00576224_2', '00576224_3', '00576224_4', '00576224_5', '00576224_6', '00576224_7', '00576224_8', '00576224_9', '00576224_10', '00576224_11', '00576224_12', '00576224_13', '00576224_14', '00576224_15', '00576224_16', '00576224_17', '00576224_18', '00576224_19', '00576224_20', '00576224_21', '00576224_22', '00576224_23', '007bbfb7_0', '007bbfb7_1', '007bbfb7_2', '007bbfb7_3', '007bbfb7_4', '007bbfb7_5', '007bbfb7_6', '007bbfb7_7', '007bbfb7_8', '007bbfb7_9', '007bbfb7_10', '007bbfb7_11', '007bbfb7_12', '007bbfb7_13', '007bbfb7_14', '007bbfb7_15', '007bbfb7_16', '007bbfb7_17', '007bbfb7_18', '007bbfb7_19', '007bbfb7_20', '007bbfb7_21', '007bbfb7_22', '007bbfb7_23', '009d5c81_0', '009d5c81_1', '009d5c81_2', '009d5c81_3', '009d5c81_4', '009d5c81_5', '009d5c81_6', '009d5c81_7', '009d5c81_8', '009d5c81_9', '009d5c81_10', '009d5c81_11', '009d5c81_12', '009d5c81_13', '009d5c81_14', '009d5c81_15', '009d5c81_16', '009d5c81_17', '009d5c81_18', '009d5c81_19
# ...

# %%
visualizer.plot_task(training_challenges['00576224_0'])

# %%
visualizer.plot_task(training_challenges['00576224_1'])

# %%
visualizer.plot_task(training_challenges['00576224_7'])

# %%
visualizer.plot_task(original_challenges['00576224'])

# %%
visualizer.plot_task(training_challenges['009d5c81'])

# %%
visualizer.plot_task(original_challenges['009d5c81'])

# %%
for key in list(training_challenges.keys())[:10]:
    if key not in original_challenges:
        print(f"Key {key} is missing in original challenges")

    print("--------------------------------------------------------------------")
    print(f"Training Challenge ID: {key}")
    visualizer.plot_task(training_challenges[key])
    visualizer.plot_task(original_challenges[key])
# Out:
# --------------------------------------------------------------------
# Training Challenge ID: 00576224
# --------------------------------------------------------------------
# Training Challenge ID: 007bbfb7
# --------------------------------------------------------------------
# Training Challenge ID: 009d5c81
# --------------------------------------------------------------------
# Training Challenge ID: 00d62c1b
# --------------------------------------------------------------------
# Training Challenge ID: 00dbd492
# --------------------------------------------------------------------
# Training Challenge ID: 017c7c7b
# --------------------------------------------------------------------
# Training Challenge ID: 025d127b
# --------------------------------------------------------------------
# Training Challenge ID: 03560426
# --------------------------------------------------------------------
# Training Challenge ID: 045e512c
# ...
